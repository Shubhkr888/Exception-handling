# %%
1/0 #Logical error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-3bdffcda2573> in <cell line: 1>()
# ----> 1 1/0 #Logical error
#
# ZeroDivisionError: division by zero

# %%
open("text.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4a8bace7e47e> in <cell line: 1>()
# ----> 1 open("text.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text.txt'

# %%
print(dir(locals()['__builtins__']))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %%
x = 10
y = 3
assert y==3,"Inavlid operation"
print(x/y)
# Out:
# 3.3333333333333335

# %%
a = 10
b = 3
assert b!=3,"Invalid operation"
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-527ed8a0ab4a> in <cell line: 3>()
#       1 a = 10
#       2 b = 3
# ----> 3 assert b!=3,"Invalid operation"
#       4 print(a/b)
#
# AssertionError: Invalid operation

# %%
y = 10
y.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-7de17ceaf3da> in <cell line: 2>()
#       1 y = 10
# ----> 2 y.append(6)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
mylist = [1,2,3,4,5]

# %%
mylist[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-4eac906abbde> in <cell line: 1>()
# ----> 1 mylist[10]
#
# IndexError: list index out of range

# %%
mydict = {
    "Name":"Shubham",
    "Course":"FSDS"
}

# %%
mydict["Age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-302a36c80766> in <cell line: 1>()
# ----> 1 mydict["Age"]
#
# KeyError: 'Age'

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.sqrt(-25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-d80dea1ee982> in <cell line: 1>()
# ----> 1 math.sqrt(-25)
#
# ValueError: math domain error

# %%
a = 6
b = int(input())
a/b
# Out:
# 2
# 3.0

# %%
try:
    a = 10
    b = 0
    c = a/b
    print(c)
except:
    print("can't divide with zero provide different no")
# Out:
# can't divide with zero provide different no

# %%
try:
    a = 10
    b = 5
    c = a/b
    print(c)
except:
    print("can't divide with zero provide different no")
# Out:
# 2.0

# %%
try:
    f = open("test.txt","r")
    f.write("ineuron")
except:
    print("there was a mistake")
# Out:
# there was a mistake

# %%
l = [4,5,6,7,8,9,9]

try:
    for i in range(len(l)):
        print(l)
except:
    print("this is not working")
# Out:
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]

# %%
l = [4,5,6,7,8,9,9]

try:
    for i in range(len(l)):
        print(l)
except:
    print("this is not working")
# Out:
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]
# [4, 5, 6, 7, 8, 9, 9]

# %%
l = [4,5,6,7,8,9,9]

try:
    for i in range(len(l)+1):
        print(l[i])
except Exception as e:
    print(e)
    print("this is not working")
# Out:
# 4
# 5
# 6
# 7
# 8
# 9
# 9
# list index out of range
# this is not working

# %%
try:
    f = open("test.txt","r")
    f.write("ineuron")
except Exception as e:
    print(e)
    print("there was a mistake")
# Out:
# [Errno 2] No such file or directory: 'test.txt'
# there was a mistake

# %%
try:
    a = int(input())
    b = int(input())
except Exception as e:
    print(e)
print("Invalid")
# Out:
# ef
# invalid literal for int() with base 10: 'ef'
# Invalid

# %%
try:
    a = int(input())
    b = int(input())
except Exception as e:
    print(e)
print("Invalid")
# Out:
# ed
# invalid literal for int() with base 10: 'ed'
# Invalid

# %%
    a = int(input())
    b = int(input())
# Out:
# 2
# 3

# %%
try:
    a = int(input("Enter a: "))
    b = int(input("Enter b: "))
    c = a/b
    print("answer",c)
except ValueError:
    print("Enter value is not integer")
except ZeroDivisionError:
    print("can't divide by zero")
# Out:
# Enter a: 2
# Enter b: 3
# answer 0.6666666666666666

# %%
try:
    a = int(input("Enter a: "))
    b = int(input("Enter b: "))
    c = a/b
    print("answer",c)
except Exception as e:
    print(e)
# Out:
# Enter a:
# invalid literal for int() with base 10: ''

# %%
f = open("test.txt","w")
f.write("ineuron")
# Out:
# 7

# %%
try:
    x = int(input())
    y = int(input())
    c = x/y
    print(c)
except:
    print("mistake occured")
# Out:
# mistake occured

# %%
try:
    f = open("test1.txt", "r")
    f.write("this is my code with exeption handling")
    print("this is my code after write ops")
except Exception as e:
    print("this is my handler",e)
l = [1,2,3,4,6]
for i in l:
    print(i)
# Out:
# this is my handler [Errno 2] No such file or directory: 'test1.txt'
# 1
# 2
# 3
# 4
# 6

# %%
try:
    d = {"key1" : "sudh", "key2" : [1,2,3,4,5], "key3" : [10,12,44,64]}
    d["key4"] = int(input())
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: ''

# %%
try:
    f = open("test1.txt","w")
    f.write("My name is shubham")
except Exception as e:
    print("Error occured",e)
else:
    print("If try run successfully then it will run successfully")
    f.close()
# Out:
# If try run successfully then it will run successfully

# %%
try:
    f = open("test3.txt","r")
    f.write("My name is shubham")
except Exception as e:
    print("Error occured",e)
else:
    print("If try run successfully then it will run successfully")
    f.close()
# Out:
# Error occured [Errno 2] No such file or directory: 'test3.txt'

# %%
try:
    f = open("test1.txt","w")
    f.write("My name is shubham")
except Exception as e:
     print("Error occured",e)
finally:
    print("this will run sure even try block failed")
# Out:
# this will run sure even try block failed

# %%
def integers():
    while(True):
        try:
            x = int(input())
            if(type(x)==int):
                break
                print("Enter the integers")
                
               
        except Exception as e:
            print(e)

# %%
integers()
# Out:
# 2

# %%
try:
    x = int(input())
except Exception as e:
    print(e)
else:
    print("executed successfully only if try block executed")
finally:
    print("always executed if also try blocks failed")
# Out:
# r
# invalid literal for int() with base 10: 'r'
# always executed if also try blocks failed
